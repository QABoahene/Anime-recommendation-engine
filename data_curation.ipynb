# %% [markdown]
# # Curating Data

# %% [markdown]
# ## Loading modules and path

# %%
import pandas as pd
from data_path import *

# %% [markdown]
# ## Loading data

# %%
anime_data = pd.read_csv(data_path + '/anime.csv')
anime_data_synopsis = pd.read_csv(data_path + '/anime_with_synopsis.csv')

# %%
anime_data
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                  Genders  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
anime_data_synopsis
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                  Genders  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %% [markdown]
# ## Merging data

# %%
all_data = pd.merge(anime_data, anime_data_synopsis)

# %%
all_data
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                  Genders  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
all_data[all_data['English name']== 'Unknown']
# Out:
#        MAL_ID                             Name    Score  \
# 5          15                     Eyeshield 21     7.95
# 7          17       Hungry Heart: Wild Striker     7.59
# 8          18           Initial D Fourth Stage     8.15
# 13         23                 Ring ni Kakero 1     6.38
# 19         29                           Zipang     7.51
# ...       ...                              ...      ...
# 16208   48480      Wan Jie Shen Zhu 3rd Season  Unknown
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                  Genders English name  \
# 5                        Action, Sports, Comedy, Shounen      Unknown
# 7                 Slice of Life, Comedy, Sports, Shounen      Unknown
# 8                    Action, Cars, Sports, Drama, Seinen      Unknown
# ...

# %%
all_data.columns = ['MAL_ID', 'Name', 'Anime rating', 'Genres', 'English name', 'Japanese name',
       'Type', 'Episodes', 'Aired', 'Premiered', 'Producers', 'Licensors',
       'Studios', 'Source', 'Duration', 'Rating', 'Ranked', 'Popularity',
       'Members', 'Favorites', 'Watching', 'Completed', 'On-Hold', 'Dropped',
       'Plan to Watch', 'Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6',
       'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1', 'synopsis']

# %%
# Select duplicate rows except first occurrence based on all columns
duplicateRowsDF = all_data[all_data.duplicated()]
print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateRowsDF)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# Empty DataFrame
# Columns: [MAL_ID, Name, Anime rating, Genres, English name, Japanese name, Type, Episodes, Aired, Premiered, Producers, Licensors, Studios, Source, Duration, Rating, Ranked, Popularity, Members, Favorites, Watching, Completed, On-Hold, Dropped, Plan to Watch, Score-10, Score-9, Score-8, Score-7, Score-6, Score-5, Score-4, Score-3, Score-2, Score-1, synopsis]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# ## Saving merged data

# %%
all_data.to_csv(data_path +'/'+ 'all_anime_data.csv', index = False)
