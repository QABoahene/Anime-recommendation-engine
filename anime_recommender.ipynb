# %% [markdown]
# # ANIME RECOMMENDER
# ---

# %% [markdown]
# `DESIGN`
#
# The idea is to use the advantage of empath themes to help the user pick what anime they want recommendations based off on.
#
# **STEPS**
# - load pickled data.
# - finalise data to be used.
# - create empath search functionality to give the most popular(one item) anime with that empath theme.
# - use the title of the most popular anime as seed for recommendation.
# - give the user top 10 anime based on the seed to watch which is about the empath.
#
# **features to use**
#
# `anime data`:
# anime id (MAL_ID), score, name, genre, type, episodes, rating, members, popularity
#
# `user rating data`: user id, anime id, rating
#
# ---

# %% [markdown]
# ## Modules import

# %%
# Importing needed modules and setting parameters
import pandas as pd
import os
import numpy as np
import json
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import matplotlib.pylab as pylab
import inflect
import ipywidgets as widgets
import warnings
from IPython.display import HTML, display
from nltk.corpus import wordnet
from clustering import *

warnings.filterwarnings('ignore')
nltk.download('wordnet', quiet=True)

with open('config.json') as json_data_file:
    config = json.load(json_data_file)

# %% [markdown]
# ## Data import and curation

# %%
anime_rec_data = pd.read_pickle(
    os.path.join(config['Data_path'], 'final_recommendation_anime_data.pck'))
anime_rec_data
# Out:
#           anime_id                title english_title  \
# 0                1         Cowboy Bebop  Cowboy Bebop
# 1                1         Cowboy Bebop  Cowboy Bebop
# 2                1         Cowboy Bebop  Cowboy Bebop
# 3                1         Cowboy Bebop  Cowboy Bebop
# 4                1         Cowboy Bebop  Cowboy Bebop
# ...            ...                  ...           ...
# 56726856     48456  SK∞: Crazy Rock Jam       Unknown
# 56726857     48456  SK∞: Crazy Rock Jam       Unknown
# 56726858     48456  SK∞: Crazy Rock Jam       Unknown
# 56726859     48456  SK∞: Crazy Rock Jam       Unknown
# 56726860     48456  SK∞: Crazy Rock Jam       Unknown
#
#                                                    genres  anime_rating  \
# 0         Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
# 1         Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
# 2         Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
# 3         Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
# 4         Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
# ...                                                   ...           ...
# 56726856                                   Comedy, Sports          6.52
# 56726857                                   Comedy, Sports          6.52
# 56726858                                   Comedy, Sports          6.52
# 56726859                                   Comedy, Sports          6.52
# 56726860                                   Comedy, Sports          6.52
#
#                                                    synopsis  \
# 0         In the year 2071, humanity has colonized sever...
# 1         In the year 2071, humanity has colonized sever...
# 2         In the year 2071, humanity has colonized sever...
# 3         In the year 2071, humanity has colonized sever...
# 4         In the year 2071, humanity has colonized sever...
# ...                                                     ...
# 56726856                   cap of the first 9 episodes of .
# 56726857                   cap of the first 9 episodes of .
# 56726858                   cap of the first 9 episodes of .
# 56726859                   cap of the first 9 episodes of .
# 56726860                   cap of the first 9 episodes of .
#
#                                               empath_themes     type episodes  \
# 0         superhero music fun musical stealing crime art...       TV       26
# 1         superhero music fun musical stealing crime art...       TV       26
# 2         superhero music fun musical stealing crime art...       TV       26
# 3         superhero music fun musical stealing crime art...       TV       26
# 4         superhero music fun musical stealing crime art...       TV       26
# ...                                                     ...      ...      ...
# 56726856                                                     Special        1
# 56726857                                                     Special        1
# 56726858                                                     Special        1
# 56726859                                                     Special        1
# 56726860                                                     Special        1
#
#           members  popularity  user_id  rating
# 0         1251960          39        3       9
# 1         1251960          39        6       6
# 2         1251960          39       14       9
# 3         1251960          39       19       8
# 4         1251960          39       22       9
# ...           ...         ...      ...     ...
# 56726856    10722        4830   342067       5
# 56726857    10722        4830   347462       4
# 56726858    10722        4830   348266       5
# 56726859    10722        4830   348321       6
# 56726860    10722        4830   349233       7
#
# [56726861 rows x 13 columns]

# %%
anime_rec_data_copy = anime_rec_data.copy()
anime_rec_data_copy['rating'].replace({-1: np.nan}, inplace = True)
anime_rec_data_copy.head()
# Out:
#    anime_id         title english_title  \
# 0         1  Cowboy Bebop  Cowboy Bebop
# 1         1  Cowboy Bebop  Cowboy Bebop
# 2         1  Cowboy Bebop  Cowboy Bebop
# 3         1  Cowboy Bebop  Cowboy Bebop
# 4         1  Cowboy Bebop  Cowboy Bebop
#
#                                             genres  anime_rating  \
# 0  Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
# 1  Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
# 2  Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
# 3  Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
# 4  Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
#
#                                             synopsis  \
# 0  In the year 2071, humanity has colonized sever...
# 1  In the year 2071, humanity has colonized sever...
# 2  In the year 2071, humanity has colonized sever...
# 3  In the year 2071, humanity has colonized sever...
# 4  In the year 2071, humanity has colonized sever...
#
#                                        empath_themes type episodes  members  \
# 0  superhero music fun musical stealing crime art...   TV       26  1251960
# 1  superhero music fun musical stealing crime art...   TV       26  1251960
# 2  superhero music fun musical stealing crime art...   TV       26  1251960
# 3  superhero music fun musical stealing crime art...   TV       26  1251960
# 4  superhero music fun musical stealing crime art...   TV       26  1251960
#
#    popularity  user_id  rating
# 0          39        3       9
# 1          39        6       6
# 2          39       14       9
# 3          39       19       8
# 4          39       22       9

# %%
anime_rec_data_copy = anime_rec_data_copy.dropna(axis = 0, how = 'any')
anime_rec_data_copy.isnull().sum()
# Out:
# anime_id         0
# title            0
# english_title    0
# genres           0
# anime_rating     0
# synopsis         0
# empath_themes    0
# type             0
# episodes         0
# members          0
# popularity       0
# user_id          0
# rating           0
# dtype: int64

# %%
anime_rec_data_copy['user_id'].value_counts()
# Out:
# 189037    10484
# 68042     10063
# 283786    10057
# 162615    10028
# 259790     8421
#           ...
# 99842         1
# 140184        1
# 258522        1
# 247751        1
# 123349        1
# Name: user_id, Length: 309480, dtype: int64

# %%
counts = anime_rec_data_copy['user_id'].value_counts()
anime_rec_data_copy = anime_rec_data_copy[anime_rec_data_copy['user_id'].isin(
    counts[counts >= 800].index)]

# %% [markdown]
# ## Using empath themes to select seed anime title for recommendation

# %%
anime_seed_data = pd.read_pickle(
    os.path.join(config['Data_path'], 'final_empath_recommendation_anime_data.pck'))
anime_seed_data
# Out:
#        anime_id                            title  \
# 0             1                     Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira
# 2             6                           Trigun
# 3             7               Witch Hunter Robin
# 4             8                   Bouken Ou Beet
# ...         ...                              ...
# 16209     48481  Daomu Biji Zhi Qinling Shen Shu
# 16210     48483                     Mieruko-chan
# 16211     48488  Higurashi no Naku Koro ni Sotsu
# 16212     48491      Yama no Susume: Next Summit
# 16213     48492                    Scarlet Nexus
#
#                          english_title  \
# 0                         Cowboy Bebop
# 1               Cowboy Bebop:The Movie
# 2                               Trigun
# 3                   Witch Hunter Robin
# 4               Beet the Vandel Buster
# ...                                ...
# 16209                          Unknown
# 16210                          Unknown
# 16211  Higurashi:When They Cry – SOTSU
# 16212                          Unknown
# 16213                          Unknown
#
#                                                   genres  anime_rating  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space          8.78
# 1                  Action, Drama, Mystery, Sci-Fi, Space          8.39
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen          8.24
# 3      Action, Mystery, Police, Supernatural, Drama, ...          7.27
# 4              Adventure, Fantasy, Shounen, Supernatural          6.98
# ...                                                  ...           ...
# 16209                   Adventure, Mystery, Supernatural           NaN
# 16210                       Comedy, Horror, Supernatural           NaN
# 16211  Mystery, Dementia, Horror, Psychological, Supe...           NaN
# 16212                   Adventure, Slice of Life, Comedy           NaN
# 16213                                    Action, Fantasy           NaN
#
#                                                 synopsis  \
# 0      In the year 2071, humanity has colonized sever...
# 1      other day, another bounty—such is the life of ...
# 2      the is the man with a $$60,000,000,000 bounty ...
# 3      ches are individuals with special powers like ...
# 4      It is the dark century and the people are suff...
# ...                                                  ...
# 16209  No synopsis information has been added to this...
# 16210  ko is a typical high school student whose life...
# 16211                                  Sequel to no ni .
# 16212                                          no anime.
# 16213  calendar year 2020: grotesque organisms called...
#
#                                            empath_themes   type episodes  \
# 0      superhero music fun musical stealing crime art...     TV       26
# 1      business surprise attractive art appearance mo...  Movie        1
# 2      suffering superhero business stealing crime mo...     TV       26
# 3      business crime prison art order government con...     TV       26
# 4      suffering fun strength order traveling governm...     TV       52
# ...                                                  ...    ...      ...
# 16209  computer communication internet reading meetin...    ONA  Unknown
# 16210  hygiene suffering business surprise crime orde...     TV  Unknown
# 16211                                                        TV  Unknown
# 16212                                                        TV  Unknown
# 16213  exercise order sports dominant_heirarchical co...     TV  Unknown
#
#        members  popularity
# 0      1251960          39
# 1       273145         518
# 2       558913         201
# 3        94683        1467
# 4        13224        4369
# ...        ...         ...
# 16209      354       13116
# 16210     7010       17562
# 16211    11309       17558
# 16212     1386       17565
# 16213      310       17563
#
# [16214 rows x 11 columns]

# %%
anime_seed_data['anime_rating'].isnull().sum()
# Out:
# 5123

# %%
def find_synonym(word_entry):
    found_synonyms = []
    for synonym in wordnet.synsets(word_entry):
        for lemma in synonym.lemmas():
            found_synonyms.append(lemma.name())
    return list(set(found_synonyms))


def anime_search(value, df):
    if value == '':
        if df.shape[0] < 25:
            return df, df.shape[0]
        return df[:], df.shape[0]
    df_out = pd.DataFrame({
        'title': [],
        'english_title': [],
        'genres': [],
        'synopsis': [],
        'episodes': [],
        'anime_rating': []
    })
    x = []
    for i in value.split():
        x.extend(find_synonym(i))
    if x == []:
        df_out = df.loc[df['synopsis'].str.contains(value,
                                                         case=False,
                                                         na=False)]
    else:
        reg = ' | '.join(x)
        reg = ' ' + reg
        df_out = df.loc[df['synopsis'].str.contains(reg,
                                                         regex=True,
                                                         case=False,
                                                         na=False)]

#     if toggle == 'Tags':
#         x = value.split(' ')
#         reg = ' | '.join(x)
#         df_out = df.loc[df['empath_themes'].str.contains(' ' + reg,
#                                                          regex=True,
#                                                          case=False,
#                                                          na=False)]

    if df_out.shape[0] < 25:
        return df_out, df_out.shape[0]
    return df_out[:], df_out.shape[0]

# %%
search = widgets.Text(
    placeholder = 'Type Something',
    description = 'Search:',
    disabled = False
)
print('''
What do you look for in anime that you want to watch?
Type a word describing that.

Example: Love, Action, Food, Heroes, Fight, Magic, Powers, Anger, Sadness, etc.
''')
display(search)
print('Enter the keyword and run the next code block')
# Out:
# What do you look for in anime that you want to watch?
# Type a word describing that.
#
# Example: Love, Action, Food, Heroes, Fight, Magic, Powers, Anger, Sadness, etc.
# Text(value='', description='Search:', placeholder='Type Something')
# Enter the keyword and run the next code block

# %%
fr_sh, size = anime_search(search.value, anime_seed_data)
df = fr_sh[[
    'title', 'english_title', 'genres', 'synopsis', 'episodes', 'anime_rating'
]]
df = df.sort_values(by='anime_rating', ascending=False)
seed_title = df.iloc[0]['title']
df = df[:1].to_html(escape=False, index=False)
print('Number of anime titles about', search.value, 'is: ' + str(size))
print(
    'However, the seed anime content that will be used for the recommendation is',
    seed_title, 'because it is the highest rated anime.')
display(HTML(df))
# Out:
# Number of anime titles about Explosions is: 29
# However, the seed anime content that will be used for the recommendation is Mob Psycho 100 because it is the highest rated anime.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>title</th>
#       <th>english_title</th>
#       <th>genres</th>
#       <th>synopsis</th>
#       <th>episodes</th>
#       <th>anime_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Mob Psycho 100</td>
#       <td>Mob Psycho 100</td>
#       <td>Action, Slice of Life, Comedy, Supernatural</td>
#       <td>has tapped into his inner wellspring of psychic prowess at a young age. But the power quickly proves to be a liability when he realizes the potential danger in his skills. Choosing to suppress his power, only present use for his ability is to impress his longtime crush, who soon grows bored of the same tricks. In order to effectuate control on his skills, enlists himself under the wing of a con artist claiming to be a psychic, who exploits powers for pocket change. exorcising evil spirits on command has become a part of daily, monotonous life. the psychic energy he exerts is barely the tip of the iceberg; if his vast potential and unrestrained emotions run berserk, a cataclysmic event that would render him completely unrecognizable will be triggered. The progression toward explosion is rising and attempting to stop it is futile.</td>
#       <td>12</td>
#       <td>8.49</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# So the code to search for the anime title basically takes the input and searches through either the synopsis or the empath themes to find similar content having that. But that's not so great. I think it becomes quite a dumb way to perform the search and I will be handicaped by the empath themes. I think the best way for the empath thems to be handled is to adjust the code to give me the top 5 or n number of empath themes then use those as a list to create categories. According to how the the empath library works, it can create categories for words so the idea is to create categories for each empath theme, then generate some score for how many of those categories are in the synopsis.
#
# Another way I'm looking at this is to use the synonyms. The synonyms for the words provide a list of words. The list can then be used as a measure for a new column which combines the synopsis, categories as well as the empath themes. A score should be generated for the percentage of the synonyms are in this new column. When the percentages/measure are generated for the matching, the title with the highest percentage will be used as a seed content for the recommendation.
#
# A list however should be created first so the code won't be combing through all the data. The above (last) idea should use a bit of its process here. Maybe the synonyms for the word shows a list of content with that has the synonyms in its synopsis. Then that list would be used for the generation of measures.
#
# Maybe the categories for the top 5 empath themes can be created as an available database. That will make the process faster which means we only draw out the synonyms of an input then get the measure of those synonyms in the cell with the combined synopsis, categories and empath themes.
#
# Investigate using fuzzy matching for this measure creation.

# %%
seed_data_matrix = tfidf_empath(anime_seed_data)
seed_data_matrix.shape
# Out:
# (16214, 1970)

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

# Compute the sigmoid kernel
sig = sigmoid_kernel(seed_data_matrix, seed_data_matrix)

# %%
seed_data_indices = pd.Series(anime_seed_data.index, index=anime_seed_data['title']).drop_duplicates()

# %%
def give_rec(title, sig=sig):
    # Get the index corresponding to original_title
    idx = seed_data_indices[title]

    # Get the pairwsie similarity scores
    sig_scores = list(enumerate(sig[idx]))

    # Sort the movies
    sig_scores = sorted(sig_scores, key=lambda x: x[1], reverse=True)

    # Scores of the 10 most similar movies
    sig_scores = sig_scores[1:16]

    # Movie indices
    anime_indices = [i[0] for i in sig_scores]

    # Top 10 most similar movies
    anime_rec = pd.DataFrame({
        'Anime Title':
        anime_seed_data['title'].iloc[anime_indices].values,
        'English Title':
        anime_seed_data['english_title'].iloc[anime_indices].values,
        'Rating':
        anime_seed_data['anime_rating'].iloc[anime_indices].values
    })
    anime_rec = anime_rec.sort_values(by='Rating', ascending=False)
    
    return anime_rec

# %%
display(HTML(give_rec(seed_title).to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Anime Title</th>
#       <th>English Title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Code Geass: Boukoku no Akito 2 - Hikisakareshi Yokuryuu</td>
#       <td>Code Geass:Akito the Exiled - The Wyvern Divided</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Detective Conan Movie 16: The Eleventh Striker</td>
#       <td>Unknown</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Taimadou Gakuen 35 Shiken Shoutai</td>
#       <td>AntiMagic Academy 35th Test Platoon</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Kekkai Sensen &amp; Beyond</td>
#       <td>Blood Blockade Battlefront &amp; Beyond</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Akira</td>
#       <td>AKIRA</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Makyou Gaiden Le Deus</td>
#       <td>Ladius</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Carol</td>
#       <td>Unknown</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Bucket no Naka no Kaka</td>
#       <td>Kaka in the bucket.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Kakumeiki Valvrave 2nd Season</td>
#       <td>Valvrave the Liberator 2nd Season</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Speed Grapher</td>
#       <td>Speed Grapher</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Yaoguai Mingdan</td>
#       <td>Monster List</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Rental Magica</td>
#       <td>Rental Magica</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Xanadu Dragonslayer Densetsu</td>
#       <td>Unknown</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Otogi Juushi Akazukin</td>
#       <td>Fairy Musketeers</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Bishoujo Senshi Sailor Moon R</td>
#       <td>Sailor Moon R</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# `TO DO:` \
# - Remove titles with unknown in them.
# - Remove titles with the ratings of 'NaN'.
# - Change display names in cluster to english names.
